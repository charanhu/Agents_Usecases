# %%
# !pip install perplexityai

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from perplexity import Perplexity

# Initialize the client (uses PERPLEXITY_API_KEY environment variable)
client = Perplexity()

# Make the API call
completion = client.chat.completions.create(
    model="sonar-pro",
    messages=[
        {"role": "user", "content": "2025 IPL winner?"}
    ]
)

# Print the AI's response
print(completion.choices[0].message.content)
# Out:
# The **2025 IPL (Indian Premier League) winner was Royal Challengers Bengaluru (RCB)**.
#
# They defeated **Punjab Kings by 6 runs in the final** to claim their **maiden IPL title** after an 18-year wait.[1][2][3][6]

# %%
from perplexity import Perplexity

# Initialize the client (uses PERPLEXITY_API_KEY environment variable)
client = Perplexity()

# Make the streaming API call
stream = client.chat.completions.create(
    model="sonar-pro",
    messages=[
        {"role": "user", "content": "Who won 2025 IPL?, write in bullet points."}
    ],
    stream=True
)

# Process the streaming response
for chunk in stream:
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end="")
# Out:
# - **Winner:** Royal Challengers Bengaluru (RCB) won the **2025 Indian Premier League (IPL)**.[2][5]
# - **Final result:** RCB defeated **Punjab Kings (PBKS)** by **6 runs** in the final.[1][2]
# - **Title note:** This was RCB’s **maiden IPL title** after 18 seasons.[2][5]
